# %%
# 1. Read excel file from vgsales.xlsx
# 2. Convert the pandas into spark dataframe
# 3. Save the spark dataframe into a table

# %%
import pandas as pd

# %%
vgsales_path = '/Volumes/workspace/01_bronze/files/vgsales.csv'
vgsales_pd = pd.read_csv(vgsales_path)

# %%
vgsales_spark = spark.createDataFrame(vgsales_pd)
vgsales_spark.write.mode("overwrite").saveAsTable('workspace.01_bronze.kaggle_games')
